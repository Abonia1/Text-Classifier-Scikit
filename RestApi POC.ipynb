# %%
import flask
from flask import Flask, jsonify
from sklearn.externals import joblib
import pandas as pd

app = flask.Flask(__name__)


@app.route('/predict', methods=['POST'])
def predict():
     json_ = request.json
     query_df = pd.DataFrame(json_)
     query = pd.get_dummies(query_df)
     prediction = clf.predict(query)
     return jsonify({'prediction': list(prediction)})
    if __name__ == '__main__':
     clf = joblib.load('model.pkl')
     app.run(port=8080)



from sklearn.externals import joblib

classifier = joblib.load('model.joblib')


#Select needed category for your training
categories=['ABSENCES','AVANTAGES SOCIETE GENERALE',"DEPART DE L'ENTREPRISE",'OUTILS RH','PAIE, REMUNERATION ET FRAIS PROFESSIONNELS','THEME AUTRE','DONNEES PERSONNELLES','FORMATION','INTERIM  STAGES  EXTERNES','MUTUELLE  PREVOYANCE','PARCOURS PROFESSIONNEL','TEMPS DE TRAVAIL']

docs_to_train = sklearn.datasets.load_files("document", 
    description=None, categories=categories, 
    load_content=True, encoding='utf-8', shuffle=True, random_state=0)
docs_to_train .target_names

#Split data for train and test set
X_train, X_test, y_train, y_test = train_test_split(docs_to_train.data,
    docs_to_train.target, test_size=0.3,random_state=42)


# Construct the classifier pipeline using a SGDClassifier algorithm
print ('\nApplying the classifier...\n')

text_clf = Pipeline([('vect', CountVectorizer(stop_words='english')),

                     ('tfidf', TfidfTransformer(use_idf=True)),

                     ('clf', SGDClassifier(loss='hinge', penalty='l2',alpha=1e-5, random_state=0, verbose=1,max_iter=5)),])

#Fit train data with classifier
text_clf.fit(X_train, y_train)

#Predict test data using classifier
predicted = text_clf.predict(X_test)



if __name__ == '__main__':

    HOST = '127.0.0.1'

    PORT = 4000      #make sure this is an integer



app.run(HOST, PORT)

# %%
import connexion
app = connexion.App(__name__)
app.add_api('swagger.yaml')

if __name__ == '__main__':
    app.run(port=8080, server='gevent')
    
    
from sklearn.externals import joblib

classifier = joblib.load('/model.pkl')


def post_predictions(query):
    predictions = []
    for item in query:
        text = item['text']
        category = classifier.predict([text])[0]
        predictions.append({"category": category, "text": text})
    return predictions

# %%
import flask
from flask import Flask, jsonify
from sklearn.externals import joblib
import pandas as pd

app = flask.Flask(__name__)


@app.route('/predict', methods=['POST'])
def predict():
     json_ = request.json
     query_df = pd.DataFrame(json_)
     query = pd.get_dummies(query_df)
     prediction = clf.predict(query)
     return jsonify({'prediction': list(prediction)})
     if __name__ == '__main__':
         clf = joblib.load('model.pkl')
        
     host='127.0.0.1'
     port=4000
     app.run(host,port)

# %%
import connexion
app = connexion.App(__name__)
    #swagger_path="C:/Users/asojasingarayar/AppData/Local/Continuum/anaconda/Lib/site-packages/connexion/vendor/swaghger-ui"
app.add_api('swagger.yaml')




from sklearn.externals import joblib

classifier = joblib.load('model.pkl')


def post_predictions(query):
    predictions = []
    for item in query:
        text = item['text']
        category = classifier.predict([text])[0]
        predictions.append({"category": category, "text": text})
    return predictions

if __name__ == '__main__':
    app.run(port=8080, server='gevent')
# Out:
# Failed to add operation for POST /predictions
# Failed to add operation for POST /predictions
# ---------------------------------------------------------------------------
# ResolverError                             Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda\lib\site-packages\connexion\apis\abstract.py in add_paths(self, paths)
#     261                 try:
# --> 262                     self.add_operation(method, path, endpoint, path_parameters)
#     263                 except ResolverError as err:
#
# ~\AppData\Local\Continuum\anaconda\lib\site-packages\connexion\apis\abstract.py in add_operation(self, method, path, swagger_operation, path_parameters)
#     214                               uri_parser_class=self.options.uri_parser_class,
# --> 215                               pass_context_arg_name=self.pass_context_arg_name)
#     216         self._add_operation_internal(method, path, operation)
#
# ~\AppData\Local\Continuum\anaconda\lib\site-packages\connexion\operation.py in __init__(self, api, method, path, operation, resolver, app_produces, app_consumes, path_parameters, app_security, security_definitions, definitions, parameter_definitions, response_definitions, validate_responses, strict_validation, randomize_endpoint, validator_map, pythonic_params, uri_parser_class, pass_context_arg_name)
#     227
# --> 228         resolution = resolver.resolve(self)
#     229         self.operation_id = resolution.operation_id
#
# ~\AppData\Local\Continuum\anaconda\lib\site-packages\connexion\resolver.py in resolve(self, operation)
#      39         operation_id = self.resolve_operation_id(operation)
# ---> 40         return Resolution(self.resolve_function_from_operation_id(operation_id), operation_id)
#      41
#
# ~\AppData\Local\Continuum\anaconda\lib\site-packages\connexion\resolver.py in resolve_function_from_operation_id(self, operation_id)
#      66         except (AttributeError, ValueError) as e:
# ---> 67             raise ResolverError(str(e), sys.exc_info())
#      68
#
# ResolverError: <ResolverError: module 'app' has no attribute 'post_predictions'>
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-7169af3c2a01> in <module>()
#       2 app = connexion.App(__name__)
#       3 #swagger_path="C:/Users/asojasingarayar/AppData/Local/Continuum/anaconda/Lib/site-packages/connexion/vendor/swaghger-ui"
# ----> 4 app.add_api('swagger.yaml')
#       5
#       6
#
# ~\AppData\Local\Continuum\anaconda\lib\site-packages\connexion\apps\flask_app.py in add_api(self, specification, **kwargs)
#      52
#      53     def add_api(self, specification, **kwargs):
# ---> 54         api = super(FlaskApp, self).add_api(specification, **kwargs)
#      55         self.app.register_blueprint(api.blueprint)
#      56         return api
#
# ~\AppData\Local\Continuum\anaconda\lib\site-packages\connexion\apps\abstract.py in add_api(self, specification, base_path, arguments, auth_all_paths, validate_responses, strict_validation, resolver, resolver_error, pythonic_params, options, pass_context_arg_name, **old_style_options)
#     160                            pythonic_params=pythonic_params,
#     161                            pass_context_arg_name=pass_context_arg_name,
# --> 162                            options=api_options.as_dict())
#     163         return api
#     164
#
# ~\AppData\Local\Continuum\anaconda\lib\site-packages\connexion\apis\abstract.py in __init__(self, specification, base_path, arguments, validate_responses, strict_validation, resolver, auth_all_paths, debug, resolver_error_handler, validator_map, pythonic_params, options, pass_context_arg_name, **old_style_options)
#     144             self.add_swagger_ui()
#     145
# --> 146         self.add_paths()
#     147
#     148         if auth_all_paths:
#
# ~\AppData\Local\Continuum\anaconda\lib\site-packages\connexion\apis\abstract.py in add_paths(self, paths)
#     267                         self._add_resolver_error_handler(method, path, err)
#     268                     else:
# --> 269                         self._handle_add_operation_error(path, method, err.exc_info)
#     270                 except Exception:
#     271                     # All other relevant exceptions should be handled as well.
#
# ~\AppData\Local\Continuum\anaconda\lib\site-packages\connexion\apis\abstract.py in _handle_add_operation_error(self, path, method, exc_info)
#     281         else:
#     282             logger.error(error_msg)
# --> 283             six.reraise(*exc_info)
#     284
#     285     def load_spec_from_file(self, arguments, specification):
#
# ~\AppData\Local\Continuum\anaconda\lib\site-packages\six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# ~\AppData\Local\Continuum\anaconda\lib\site-packages\connexion\resolver.py in resolve_function_from_operation_id(self, operation_id)
#      60         """
#      61         try:
# ---> 62             return self.function_resolver(operation_id)
#      63         except ImportError as e:
#      64             msg = 'Cannot resolve operationId "{}"! Import error was "{}"'.format(operation_id, str(e))
#
# ~\AppData\Local\Continuum\anaconda\lib\site-packages\connexion\utils.py in get_function_from_name(function_name)
#      34     while not module:
#      35         try:
# ---> 36             module = importlib.import_module(module_name)
#      37         except ImportError as import_error:
#      38             last_import_error = import_error
#
# ~\AppData\Local\Continuum\anaconda\lib\importlib\__init__.py in import_module(name, package)
#     124                 break
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#     128
#
# ~\AppData\Local\Continuum\anaconda\lib\importlib\_bootstrap.py in _gcd_import(name, package, level)
#
# ~\AppData\Local\Continuum\anaconda\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# ~\AppData\Local\Continuum\anaconda\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~\AppData\Local\Continuum\anaconda\lib\importlib\_bootstrap.py in _load_unlocked(spec)
#
# ~\AppData\Local\Continuum\anaconda\lib\importlib\_bootstrap_external.py in exec_module(self, module)
#
# ~\AppData\Local\Continuum\anaconda\lib\importlib\_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~\CaseClassification\CaseClassifier\app.py in <module>()
#       2 app = connexion.App(__name__)
#       3 #swagger_path="C:/Users/asojasingarayar/AppData/Local/Continuum/anaconda/Lib/site-packages/connexion/vendor/swaghger-ui"
# ----> 4 app.add_api('swagger.yaml')
#       5
#       6
#
# ~\AppData\Local\Continuum\anaconda\lib\site-packages\connexion\apps\flask_app.py in add_api(self, specification, **kwargs)
#      52
#      53     def add_api(self, specification, **kwargs):
# ---> 54         api = super(FlaskApp, self).add_api(specification, **kwargs)
#      55         self.app.register_blueprint(api.blueprint)
#      56         return api
#
# ~\AppData\Local\Continuum\anaconda\lib\site-packages\connexion\apps\abstract.py in add_api(self, specification, base_path, arguments, auth_all_paths, validate_responses, strict_validation, resolver, resolver_error, pythonic_params, options, pass_context_arg_name, **old_style_options)
#     160                            pythonic_params=pythonic_params,
#     161                            pass_context_arg_name=pass_context_arg_name,
# --> 162                            options=api_options.as_dict())
#     163         return api
#     164
#
# ~\AppData\Local\Continuum\anaconda\lib\site-packages\connexion\apis\abstract.py in __init__(self, specification, base_path, arguments, validate_responses, strict_validation, resolver, auth_all_paths, debug, resolver_error_handler, validator_map, pythonic_params, options, pass_context_arg_name, **old_style_options)
#     144             self.add_swagger_ui()
#     145
# --> 146         self.add_paths()
#     147
#     148         if auth_all_paths:
#
# ~\AppData\Local\Continuum\anaconda\lib\site-packages\connexion\apis\abstract.py in add_paths(self, paths)
#     267                         self._add_resolver_error_handler(method, path, err)
#     268                     else:
# --> 269                         self._handle_add_operation_error(path, method, err.exc_info)
#     270                 except Exception:
#     271                     # All other relevant exceptions should be handled as well.
#
# ~\AppData\Local\Continuum\anaconda\lib\site-packages\connexion\apis\abstract.py in _handle_add_operation_error(self, path, method, exc_info)
#     281         else:
#     282             logger.error(error_msg)
# --> 283             six.reraise(*exc_info)
#     284
#     285     def load_spec_from_file(self, arguments, specification):
#
# ~\AppData\Local\Continuum\anaconda\lib\site-packages\six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# ~\AppData\Local\Continuum\anaconda\lib\site-packages\connexion\resolver.py in resolve_function_from_operation_id(self, operation_id)
#      60         """
#      61         try:
# ---> 62             return self.function_resolver(operation_id)
#      63         except ImportError as e:
#      64             msg = 'Cannot resolve operationId "{}"! Import error was "{}"'.format(operation_id, str(e))
#
# ~\AppData\Local\Continuum\anaconda\lib\site-packages\connexion\utils.py in get_function_from_name(function_name)
#      43                 raise
#      44     try:
# ---> 45         function = deep_getattr(module, attr_path)
#      46     except AttributeError:
#      47         if last_import_error:
#
# ~\AppData\Local\Continuum\anaconda\lib\site-packages\connexion\utils.py in deep_getattr(obj, attr)
#      11     Stolen from http://pingfive.typepad.com/blog/2010/04/deep-getattr-python-function.html
#      12     """
# ---> 13     return functools.reduce(getattr, attr.split('.'), obj)
#      14
#      15
#
# AttributeError: module 'app' has no attribute 'post_predictions'
